# %%
s="GATATATGCATATACTT"
t="ATAT"
tlen = len(t)
positionlist = ''

# %%
filename = "/Users/alexandriamiley/Desktop/Rosalind/BioinformaticsStronghold/data/rosalind_subs.txt"

with open(filename) as f:
    contents = f.readlines()
    
s = contents[0]
print(s)
t = contents[1].strip()
print(t)
tlen = len(t)
print(tlen)
positionlist = ''
# Out:
# ...
#
# TAATCGTTA
# 9

# %%
for position in range(len(s)):
    matchstring=s[position:tlen]
    print(matchstring,t)
    if t == matchstring:
        positionlist+=str(position+1)+" "
        print(str(position+1))
    tlen+=1
# Out:
# TAATCGTTA TAATCGTTA
# 1
# AATCGTTAA TAATCGTTA
# ATCGTTAAT TAATCGTTA
# TCGTTAATC TAATCGTTA
# CGTTAATCG TAATCGTTA
# GTTAATCGT TAATCGTTA
# TTAATCGTG TAATCGTTA
# TAATCGTGT TAATCGTTA
# AATCGTGTG TAATCGTTA
# ATCGTGTGA TAATCGTTA
# TCGTGTGAT TAATCGTTA
# CGTGTGATA TAATCGTTA
# GTGTGATAA TAATCGTTA
# TGTGATAAT TAATCGTTA
# GTGATAATC TAATCGTTA
# TGATAATCG TAATCGTTA
# GATAATCGT TAATCGTTA
# ATAATCGTA TAATCGTTA
# TAATCGTAT TAATCGTTA
# AATCGTATT TAATCGTTA
# ATCGTATTT TAATCGTTA
# TCGTATTTA TAATCGTTA
# CGTATTTAA TAATCGTTA
# GTATTTAAT TAATCGTTA
# TATTTAATC TAATCGTTA
# ATTTAATCG TAATCGTTA
# TTTAATCGT TAATCGTTA
# TTAATCGTG TAATCGTTA
# TAATCGTGC TAATCGTTA
# AATCGTGCT TAATCGTTA
# ATCGTGCTT TAATCGTTA
# TCGTGCTTC TAATCGTTA
# CGTGCTTCT TAATCGTTA
# GTGCTTCTC TAATCGTTA
# TGCTTCTCT TAATCGTTA
# GCTTCTCTA TAATCGTTA
# CTTCTCTAA TAATCGTTA
# TTCTCTAAT TAATCGTTA
# TCTCTAATC TAATCGTTA
# CTCTAATCG TAATCGTTA
# TCTAATCGT TAATCGTTA
# CTAATCGTC TAATCGTTA
# TAATCGTCA TAATCGTTA
# AATCGTCAT TAATCGTTA
# ATCGTCATA TAATCGTTA
# ...

# %%
str(positionlist)
# Out:
# '1 100 123 130 162 169 275 292 308 323 330 401 433 605 645 685 730 737 744 805 851 '
